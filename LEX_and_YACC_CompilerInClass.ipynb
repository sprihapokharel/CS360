# %% [markdown]
# <a href="https://colab.research.google.com/github/krusegw/cs360InClass/blob/main/LEX_and_YACC_CompilerInClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LEX and YACC Compiler in Colab
#
# Drawbacks:
# * Regular interrupts (Ctrl+D, Ctrl+C) for shell won't work in Colab while inputting for program.
# <br>Workaround: Store your inputs in a txt file and pass it to the program.

# %%
#@title Install *prerqeuisites* (run this cell first to work on LEX/YACC)
# !sudo apt install flex bison
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# bison is already the newest version (2:3.8.2+dfsg-1build1).
# flex is already the newest version (2.6.4-8build2).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.

# %% [markdown]
# ## Lex only

# %%
#@title Writing Lex program
# %%writefile program.l
# %{
    int yylineno;
%}
%%
^(.*)\n    printf("%4d\t%s", yylineno-1, yytext);
%%

int yywrap(void) {
    return 1;
}

int main(int argc, char *argv[]) {
    if(argc!=2){
        printf("Usage:\n\t./a.out <FILENAME>\n");
        exit(0);
    }

    yyin=fopen(argv[1],"r");

    yylex();
    fclose(yyin);
}
# Out:
# Overwriting program.l

# %% [markdown]
# if you want to use at txt as an input

# %%
# %%writefile program.txt
# "This is a sample file.
# Modify it as you like.
# Good luck learning lex using
# this simulator."
# Out:
# Overwriting program.txt

# %%
#@title Shell Execution (you can rewrite the commands as per your need, eg. if you want to include a file as an input)
# %%shell

lex -l program.l
gcc lex.yy.c
./a.out program.txt
# Out:
#    1	"This is a sample file.
#    2	Modify it as you like.
#    3	Good luck learning lex using
#    4	this simulator."
